# %%
import pandas as pd

# %%
dataset = pd.read_csv('Dataset\BC250_2017_Terra_Indigena_A.csv')

# %%
dataset.head()
# Out:
#                              FID  id_objeto                      nome  \
# 0  BC250_2017_Terra_Indigena_A.1          1                   Pacheca
# 1  BC250_2017_Terra_Indigena_A.2          2                 Cantagalo
# 2  BC250_2017_Terra_Indigena_A.3          3  Guarani de Águas Brancas
# 3  BC250_2017_Terra_Indigena_A.4          4                  Capivari
# 4  BC250_2017_Terra_Indigena_A.5          5     Salto Grande do Jacuí
#
#                   nomeabrev geometriaaproximada  perimetrooficial  \
# 0                   Pacheca                 Não        28109800.0
# 1                 Cantagalo                 Não          885605.0
# 2  Guarani de Águas Brancas                 Não         9000000.0
# 3                  Capivari                 Não         3465950.0
# 4     Salto Grande do Jacuí                 Não         7258320.0
#
#    areaoficialha   grupoetnico datasituacaojuridica         situacaojuridica  \
# 0         185.21       Guarani            2001/1/15             Regularizada
# 1         283.68  Guarani Mbyá            2007/1/11  Homologada ou demarcada
# 2         230.00       Guarani            1996/2/13                Declarada
# 3          43.32  Guarani Mbyá             2003/1/8             Regularizada
# 4         234.96       Guarani           2002/11/20             Regularizada
#
#                      nometi  id_produtor  id_elementoprodutor  codigofunai  \
# 0                   Pacheca       250000                  2.0          NaN
# 1                 Cantagalo       250000                  3.0          NaN
# 2  Guarani de Águas Brancas       250000                  4.0          NaN
# 3                  Capivari       250000                  7.0          NaN
# 4     Salto Grande do Jacuí       250000                  1.0          NaN
#
#                                                 geom
# 0  MULTIPOLYGON (((-51.817032999999896 -31.170511...
# 1  MULTIPOLYGON (((-51.0340119999999 -30.19090999...
# 2  MULTIPOLYGON (((-51.60478499999989 -30.766948,...
# 3  MULTIPOLYGON (((-50.359660999999896 -30.359487...
# 4  MULTIPOLYGON (((-53.2281029999999 -29.07109199...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   FID                   432 non-null    object
#  1   id_objeto             432 non-null    int64
#  2   nome                  432 non-null    object
#  3   nomeabrev             428 non-null    object
#  4   geometriaaproximada   431 non-null    object
#  5   perimetrooficial      203 non-null    float64
#  6   areaoficialha         243 non-null    float64
#  7   grupoetnico           280 non-null    object
#  8   datasituacaojuridica  224 non-null    object
#  9   situacaojuridica      431 non-null    object
#  10  nometi                221 non-null    object
#  11  id_produtor           432 non-null    int64
#  12  id_elementoprodutor   424 non-null    float64
#  13  codigofunai           0 non-null      float64
#  14  geom                  432 non-null    object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 50.8+ KB

# %%
dataset = dataset.drop(columns=["FID", "geom", "codigofunai"])

# %%
dataset.head()
# Out:
#    id_objeto                      nome                 nomeabrev  \
# 0          1                   Pacheca                   Pacheca
# 1          2                 Cantagalo                 Cantagalo
# 2          3  Guarani de Águas Brancas  Guarani de Águas Brancas
# 3          4                  Capivari                  Capivari
# 4          5     Salto Grande do Jacuí     Salto Grande do Jacuí
#
#   geometriaaproximada  perimetrooficial  areaoficialha   grupoetnico  \
# 0                 Não        28109800.0         185.21       Guarani
# 1                 Não          885605.0         283.68  Guarani Mbyá
# 2                 Não         9000000.0         230.00       Guarani
# 3                 Não         3465950.0          43.32  Guarani Mbyá
# 4                 Não         7258320.0         234.96       Guarani
#
#   datasituacaojuridica         situacaojuridica                    nometi  \
# 0            2001/1/15             Regularizada                   Pacheca
# 1            2007/1/11  Homologada ou demarcada                 Cantagalo
# 2            1996/2/13                Declarada  Guarani de Águas Brancas
# 3             2003/1/8             Regularizada                  Capivari
# 4           2002/11/20             Regularizada     Salto Grande do Jacuí
#
#    id_produtor  id_elementoprodutor
# 0       250000                  2.0
# 1       250000                  3.0
# 2       250000                  4.0
# 3       250000                  7.0
# 4       250000                  1.0
